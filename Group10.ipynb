# %% [markdown]
# <div style="background-color: #1a1a1a; padding: 25px; border-radius: 15px; border-left: 10px solid #8A2BE2; color: #ffffff; font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;">
#
# <h1 style="color: #8A2BE2; margin-bottom: 5px;">🚀 RT-DETR vs YOLO: Phase 2</h1>
# <p style="font-size: 1.1em; opacity: 0.8;">Implementation, Visual Comparison & Architectural Improvements</p>
#
# <hr style="border: 0.5px solid #333; margin: 20px 0;">
#
# <table style="width:100%; border-spacing: 15px;">
# <tr>
#
# <td style="background: #262626; padding: 15px; border-radius: 10px; vertical-align: top;">
#     <h3 style="color: #FFD700; margin-top: 0;">🔍 Baseline Evaluation</h3>
#     <ul style="list-style-type: none; padding-left: 0;">
#         <li><b>01.</b> Environment Setup</li>
#         <li><b>02.</b> Architecture Deep-Dive</li>
#         <li><b>03.</b> YOLO Inference & Metrics</li>
#         <li><b>04.</b> RT-DETR Standard Inference</li>
#         <li><b>05.</b> Side-by-Side Visuals</li>
#     </ul>
# </td>
#
# <td style="background: #262626; padding: 15px; border-radius: 10px; vertical-align: top;">
#     <h3 style="color: #00FF7F; margin-top: 0;">🏗️ Improved Model (SAHI+)</h3>
#     <ul style="list-style-type: none; padding-left: 0;">
#         <li><b>07a.</b> SAHI Integration</li>
#         <li><b>07b.</b> EMA Module (Post-StemR)</li>
#         <li><b>07c.</b> Rep Block Implementation</li>
#         <li><b>07d.</b> Partial Conv (PConv) Optimization</li>
#         <li><b>07e.</b> Full Assembly & Ablation</li>
#     </ul>
# </td>
#
# </tr>
# </table>
#
# <div style="margin-top: 20px; padding: 10px; background: #333; border-radius: 8px; text-align: center;">
#     <span style="color: #00BFFF;"><b>Final Goal:</b></span> YOLO vs RT-DETR vs <b>Improved RT-DETR (SAHI + EMA + RepPConv)</b>
# </div>
#
# </div>
